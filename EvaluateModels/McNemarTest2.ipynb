# %%
import pandas as pd
import torch
import numpy as np
import torch.nn.functional as F
import os
import json
import matplotlib.pyplot as plt

# === Define paths to the saved runs ===
GroNLP_save_path = r"C:\Users\jefva\Documents\Master\Thesis_s2\results\final\GroNLP\Run_2025-04-23_18-28"
RoBERT_save_path = r"C:\Users\jefva\Documents\Master\Thesis_s2\results\final\roBERT\Run_2025-05-04_22-35"
mBert_save_path = r"C:\Users\jefva\Documents\Master\Thesis_s2\results\final\mBERT\Run_2025-05-08_13-53"

# === Load predictions ===
gronlp_df = pd.read_csv(os.path.join(GroNLP_save_path, "test_predictions.csv"))
robbert_df = pd.read_csv(os.path.join(RoBERT_save_path, "test_predictions.csv"))
mBert_df = pd.read_excel(os.path.join(mBert_save_path, "predictions.xlsx"))

# === Ensure all models are aligned on text ===
assert all(gronlp_df["text"] == robbert_df["text"])
assert all(gronlp_df["text"] == mBert_df["clean_text"])

# === True labels ===
true_labels = gronlp_df["true_label"].tolist()

# === Binary outcomes (correct = True/False) ===
gronlp_correct = (gronlp_df["predicted_label"] == gronlp_df["true_label"]).tolist()
robbert_correct = (robbert_df["predicted_label"] == robbert_df["true_label"]).tolist()
mbert_correct = (mBert_df["theme_id"] == mBert_df["mBERT"]).tolist()

# %% [markdown]
# MCNEMAR

# %%
from statsmodels.stats.contingency_tables import mcnemar

A = B = C = D = 0

for g, r in zip(gronlp_correct, robbert_correct):
    if g and r:
        A += 1
    elif g and not r:
        B += 1
    elif not g and r:
        C += 1
    else:
        D += 1

print(f"Contingency Table:\n[[{A}, {B}],\n [{C}, {D}]]")
# Out:
# Contingency Table:
# [[6962, 500],
#  [473, 1751]]

# %%
result = mcnemar([[A, B], [C, D]], exact=True)
print(f"p-value: {result.pvalue:.5f}")

if result.pvalue < 0.05:
    print("✅ Statistically significant difference between GroNLP and RobBERT.")
else:
    print("❌ No significant difference.")
# Out:
# p-value: 0.40456
# ❌ No significant difference.

# %% [markdown]
# WilcoX

# %%
from sklearn.metrics import classification_report
from scipy.stats import wilcoxon
import json
import os

# === Load label mapping ===
with open(os.path.join(GroNLP_save_path, "label_mappings.json"), "r", encoding="utf-8") as f:
    mappings = json.load(f)
id_to_theme = {int(k): v for k, v in mappings["id_to_theme"].items()}
unique_themes = sorted(set(id_to_theme.values()))

# === GRO-NLP ===
gronlp_true = [id_to_theme[i] for i in gronlp_df["true_label"]]
gronlp_pred = [id_to_theme[i] for i in gronlp_df["predicted_label"]]
gronlp_report = classification_report(gronlp_true, gronlp_pred, labels=unique_themes, output_dict=True, zero_division=0)
f1_gronlp = [gronlp_report[label]["f1-score"] for label in unique_themes]

# === ROBBERT ===
robbert_true = [id_to_theme[i] for i in robbert_df["true_label"]]
robbert_pred = [id_to_theme[i] for i in robbert_df["predicted_label"]]
robbert_report = classification_report(robbert_true, robbert_pred, labels=unique_themes, output_dict=True, zero_division=0)
f1_robbert = [robbert_report[label]["f1-score"] for label in unique_themes]

# === mBERT ===
mbert_true = [id_to_theme[i] for i in mBert_df["theme_id"]]
mbert_pred = [id_to_theme[i] for i in mBert_df["mBERT"]]
mbert_report = classification_report(mbert_true, mbert_pred, labels=unique_themes, output_dict=True, zero_division=0)
f1_mbert = [mbert_report[label]["f1-score"] for label in unique_themes]

# %%
stat, p = wilcoxon(f1_gronlp, f1_robbert, alternative='greater')
print(f"Wilcoxon p-value: {p:.5f}")
if p < 0.05:
    print("✅ GroNLP significantly outperforms RobBERT across themes.")
else:
    print("❌ No significant difference found.")
# Out:
# Wilcoxon p-value: 0.02693
# ✅ GroNLP significantly outperforms RobBERT across themes.

# %%
print("\nPer-class F1-score comparison:")
for theme, gr_f1, rb_f1 in zip(unique_themes, f1_gronlp, f1_robbert):
    diff = gr_f1 - rb_f1
    print(f"{theme:30s} GroNLP: {gr_f1:.2f} | RobBERT: {rb_f1:.2f} | Δ: {diff:+.2f}")
# Out:
# Per-class F1-score comparison:
# Begroting                      GroNLP: 0.77 | RobBERT: 0.73 | Δ: +0.04
# Bestuur en Beleid              GroNLP: 0.73 | RobBERT: 0.74 | Δ: -0.01
# Brussel en de Vlaamse Rand     GroNLP: 0.74 | RobBERT: 0.76 | Δ: -0.03
# Cultuur en Communicatie        GroNLP: 0.68 | RobBERT: 0.67 | Δ: +0.01
# Economie en Arbeid             GroNLP: 0.77 | RobBERT: 0.76 | Δ: +0.01
# Energie                        GroNLP: 0.75 | RobBERT: 0.74 | Δ: +0.01
# Financiën                      GroNLP: 0.73 | RobBERT: 0.73 | Δ: -0.00
# Internationaal Beleid          GroNLP: 0.73 | RobBERT: 0.70 | Δ: +0.03
# Justitie en Handhaving         GroNLP: 0.68 | RobBERT: 0.65 | Δ: +0.03
# Milieu en Landbouw             GroNLP: 0.76 | RobBERT: 0.76 | Δ: -0.00
# Mobiliteit en Infrastructuur   GroNLP: 0.87 | RobBERT: 0.87 | Δ: +0.00
# Onderwijs en Samenleving       GroNLP: 0.73 | RobBERT: 0.73 | Δ: -0.00
# Onroerend erfgoed              GroNLP: 0.68 | RobBERT: 0.68 | Δ: +0.00
# Sport                          GroNLP: 0.64 | RobBERT: 0.62 | Δ: +0.02
# Toerisme                       GroNLP: 0.65 | RobBERT: 0.64 | Δ: +0.01
# Welzijn en Gezondheid          GroNLP: 0.74 | RobBERT: 0.75 | Δ: -0.01
# Wetenschap en Innovatie        GroNLP: 0.28 | RobBERT: 0.19 | Δ: +0.09
# Wonen                          GroNLP: 0.71 | RobBERT: 0.67 | Δ: +0.04

# %%
# Bar positions
x = np.arange(len(unique_themes))
width = 0.25  # Reduced width to fit 3 bars per group

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(x - width,     f1_gronlp, width, label='GroNLP BERT')
plt.bar(x,             f1_robbert, width, label='RobBERT')
plt.bar(x + width,     f1_mbert, width, label='mBERT')

# Add labels and title
plt.ylabel('F1 Score')
plt.title('Per-Class F1 Score Comparison')
plt.yticks(size=14)
plt.xticks(x, unique_themes, rotation=45, ha='right', size=14)
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.savefig("f1.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import pandas as pd

# Combine the per-class F1 scores into a DataFrame
f1_df = pd.DataFrame({
    "Theme": unique_themes,
    "GroNLP": f1_gronlp,
    "RobBERT": f1_robbert,
    "mBERT": f1_mbert
})

# Print the full table
print(f1_df.to_string(index=False))
# Out:
#                        Theme   GroNLP  RobBERT    mBERT
#                    Begroting 0.771084 0.732283 0.790123
#            Bestuur en Beleid 0.727422 0.739680 0.715111
#   Brussel en de Vlaamse Rand 0.736842 0.764331 0.608696
#      Cultuur en Communicatie 0.682707 0.671491 0.671576
#           Economie en Arbeid 0.766067 0.755359 0.752564
#                      Energie 0.748044 0.737631 0.716418
#                    Financiën 0.729614 0.731092 0.728745
#        Internationaal Beleid 0.731070 0.697561 0.676259
#       Justitie en Handhaving 0.680162 0.645669 0.689655
#           Milieu en Landbouw 0.759344 0.764068 0.745968
# Mobiliteit en Infrastructuur 0.869364 0.868687 0.859429
#     Onderwijs en Samenleving 0.727652 0.731812 0.732382
#            Onroerend erfgoed 0.678733 0.675439 0.647619
#                        Sport 0.642857 0.619469 0.619048
#                     Toerisme 0.649007 0.637771 0.649518
#        Welzijn en Gezondheid 0.741650 0.746892 0.740019
#      Wetenschap en Innovatie 0.279070 0.188679 0.315789
#                        Wonen 0.706745 0.667647 0.706231
